# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import shapiro
np.random.seed(422)
plt.style.use('dark_background')

# %%
gaussian = lambda x, mean, std : 1/np.sqrt(2*np.pi*std**2) * np.exp(-0.5*((x-mean)/std)**2)

# %% [markdown]
# Gaussian

# %%
n = 10

X = np.random.randn(1000, n)
X_bars = np.mean(X, axis=-1)

fig, ax = plt.subplots()
values, bins, _ = ax.hist(X_bars, bins=25)
area = np.sum(np.diff(bins)*values)

x = np.linspace(-4/n**0.5,4/n**0.5,100)
X_fit = gaussian(x,0,1/n**0.5)
X_fit *= area

ax.plot(x, X_fit, label = 'True Gaussian')
plt.show()

print("P value for shapiro-Wilk test:", shapiro(X_bars).pvalue)
# Out:
# P value for shapiro-Wilk test: 0.652798593044281

# %%
n = 30

X = np.random.randn(1000, n)
X_bars = np.mean(X, axis=-1)

fig, ax = plt.subplots()
values, bins, _ = ax.hist(X_bars, bins=25)
area = np.sum(np.diff(bins)*values)

x = np.linspace(-4/n**0.5,4/n**0.5,100)
X_fit = gaussian(x,0,1/n**0.5)
X_fit *= area

ax.plot(x, X_fit, label = 'True Gaussian')
plt.show()

print("P value for shapiro-Wilk test:", shapiro(X_bars).pvalue)
# Out:
# P value for shapiro-Wilk test: 0.5365604162216187

# %%
n = 50

X = np.random.randn(1000, n)
X_bars = np.mean(X, axis=-1)

fig, ax = plt.subplots()
values, bins, _ = ax.hist(X_bars, bins=25)
area = np.sum(np.diff(bins)*values)

x = np.linspace(-4/n**0.5,4/n**0.5,100)
X_fit = gaussian(x,0,1/n**0.5)
X_fit *= area

ax.plot(x, X_fit, label = 'True Gaussian')
plt.show()

print("P value for shapiro-Wilk test:", shapiro(X_bars).pvalue)
# Out:
# P value for shapiro-Wilk test: 0.0929703339934349

# %%
n = 100

X = np.random.randn(1000, n)
X_bars = np.mean(X, axis=-1)

fig, ax = plt.subplots()
values, bins, _ = ax.hist(X_bars, bins=25)
area = np.sum(np.diff(bins)*values)

x = np.linspace(-4/n**0.5,4/n**0.5,100)
X_fit = gaussian(x,0,1/n**0.5)
X_fit *= area

ax.plot(x, X_fit, label = 'True Gaussian')
plt.show()

print("P value for shapiro-Wilk test:", shapiro(X_bars).pvalue)
# Out:
# P value for shapiro-Wilk test: 0.7387496829032898

# %% [markdown]
# Uniform

# %%
n = 10

X = np.random.uniform(0,1,[1000, n])
X_bars = np.mean(X, axis=-1)

fig, ax = plt.subplots()
values, bins, _ = ax.hist(X_bars, bins=25)
area = np.sum(np.diff(bins)*values)

x = np.linspace(0.5-4/(12*n)**0.5,0.5+4/(12*n)**0.5,100)
X_fit = gaussian(x,0.5,1/(12*n)**0.5)
X_fit *= area

ax.plot(x, X_fit, label = 'True Gaussian')
plt.show()

print("P value for shapiro-Wilk test:", shapiro(X_bars).pvalue)
# Out:
# P value for shapiro-Wilk test: 0.3522534966468811

# %%
n = 30

X = np.random.uniform(0,1,[1000, n])
X_bars = np.mean(X, axis=-1)

fig, ax = plt.subplots()
values, bins, _ = ax.hist(X_bars, bins=25)
area = np.sum(np.diff(bins)*values)

x = np.linspace(0.5-4/(12*n)**0.5,0.5+4/(12*n)**0.5,100)
X_fit = gaussian(x,0.5,1/(12*n)**0.5)
X_fit *= area

ax.plot(x, X_fit, label = 'True Gaussian')
plt.show()

print("P value for shapiro-Wilk test:", shapiro(X_bars).pvalue)
# Out:
# P value for shapiro-Wilk test: 0.5394505262374878

# %%
n = 50

X = np.random.uniform(0,1,[1000, n])
X_bars = np.mean(X, axis=-1)

fig, ax = plt.subplots()
values, bins, _ = ax.hist(X_bars, bins=25)
area = np.sum(np.diff(bins)*values)

x = np.linspace(0.5-4/(12*n)**0.5,0.5+4/(12*n)**0.5,100)
X_fit = gaussian(x,0.5,1/(12*n)**0.5)
X_fit *= area

ax.plot(x, X_fit, label = 'True Gaussian')
plt.show()

print("P value for shapiro-Wilk test:", shapiro(X_bars).pvalue)
# Out:
# P value for shapiro-Wilk test: 0.652346670627594

# %%
n = 100

X = np.random.uniform(0,1,[1000, n])
X_bars = np.mean(X, axis=-1)

fig, ax = plt.subplots()
values, bins, _ = ax.hist(X_bars, bins=25)
area = np.sum(np.diff(bins)*values)

x = np.linspace(0.5-4/(12*n)**0.5,0.5+4/(12*n)**0.5,100)
X_fit = gaussian(x,0.5,1/(12*n)**0.5)
X_fit *= area

ax.plot(x, X_fit, label = 'True Gaussian')
plt.show()

print("P value for shapiro-Wilk test:", shapiro(X_bars).pvalue)
# Out:
# P value for shapiro-Wilk test: 0.8435357809066772

# %% [markdown]
# Geometric

# %%
n = 10

X = np.random.geometric(0.35,[1000, n])
X_bars = np.mean(X, axis=-1)

fig, ax = plt.subplots()
values, bins, _ = ax.hist(X_bars, bins=25)
area = np.sum(np.diff(bins)*values)

x = np.linspace(1/0.35-4*(0.65/(0.35*0.35*n))**0.5,1/0.35+4*(0.65/(0.35*0.35*n))**0.5,100)
X_fit = gaussian(x,1/0.35,(0.65/(0.35*0.35*n))**0.5)
X_fit *= area

ax.plot(x, X_fit, label = 'True Gaussian')
plt.show()

print("P value for shapiro-Wilk test:", shapiro(X_bars).pvalue)
# Out:
# P value for shapiro-Wilk test: 1.0013983565981821e-11

# %%
n = 30

X = np.random.geometric(0.35,[1000, n])
X_bars = np.mean(X, axis=-1)

fig, ax = plt.subplots()
values, bins, _ = ax.hist(X_bars, bins=25)
area = np.sum(np.diff(bins)*values)

x = np.linspace(1/0.35-4*(0.65/(0.35*0.35*n))**0.5,1/0.35+4*(0.65/(0.35*0.35*n))**0.5,100)
X_fit = gaussian(x,1/0.35,(0.65/(0.35*0.35*n))**0.5)
X_fit *= area

ax.plot(x, X_fit, label = 'True Gaussian')
plt.show()

print("P value for shapiro-Wilk test:", shapiro(X_bars).pvalue)
# Out:
# P value for shapiro-Wilk test: 0.014990194700658321

# %%
n = 50

X = np.random.geometric(0.35,[1000, n])
X_bars = np.mean(X, axis=-1)

fig, ax = plt.subplots()
values, bins, _ = ax.hist(X_bars, bins=25)
area = np.sum(np.diff(bins)*values)

x = np.linspace(1/0.35-4*(0.65/(0.35*0.35*n))**0.5,1/0.35+4*(0.65/(0.35*0.35*n))**0.5,100)
X_fit = gaussian(x,1/0.35,(0.65/(0.35*0.35*n))**0.5)
X_fit *= area

ax.plot(x, X_fit, label = 'True Gaussian')
plt.show()

print("P value for shapiro-Wilk test:", shapiro(X_bars).pvalue)
# Out:
# P value for shapiro-Wilk test: 0.05865045264363289

# %%
n = 100

X = np.random.geometric(0.35,[1000, n])
X_bars = np.mean(X, axis=-1)

fig, ax = plt.subplots()
values, bins, _ = ax.hist(X_bars, bins=25)
area = np.sum(np.diff(bins)*values)

x = np.linspace(1/0.35-4*(0.65/(0.35*0.35*n))**0.5,1/0.35+4*(0.65/(0.35*0.35*n))**0.5,100)
X_fit = gaussian(x,1/0.35,(0.65/(0.35*0.35*n))**0.5)
X_fit *= area

ax.plot(x, X_fit, label = 'True Gaussian')
plt.show()

print("P value for shapiro-Wilk test:", shapiro(X_bars).pvalue)
# Out:
# P value for shapiro-Wilk test: 0.09479966759681702

# %% [markdown]
# Cauchy

# %%
n = 10

X = np.random.standard_cauchy(size=[1000, n])
X_bars = np.mean(X, axis=-1)

fig, ax = plt.subplots()
values, bins, _ = ax.hist(X_bars, bins=25)

plt.show()

print("P value for shapiro-Wilk test:", shapiro(X_bars).pvalue)
# Out:
# P value for shapiro-Wilk test: 0.0

# %%
n = 30

X = np.random.standard_cauchy(size=[1000, n])
X_bars = np.mean(X, axis=-1)

fig, ax = plt.subplots()
values, bins, _ = ax.hist(X_bars, bins=25)

plt.show()

print("P value for shapiro-Wilk test:", shapiro(X_bars).pvalue)
# Out:
# P value for shapiro-Wilk test: 0.0

# %%
n = 50

X = np.random.standard_cauchy(size=[1000, n])
X_bars = np.mean(X, axis=-1)

fig, ax = plt.subplots()
values, bins, _ = ax.hist(X_bars, bins=25)

plt.show()

print("P value for shapiro-Wilk test:", shapiro(X_bars).pvalue)
# Out:
# P value for shapiro-Wilk test: 0.0

# %%
n = 100

X = np.random.standard_cauchy(size=[1000, n])
X_bars = np.mean(X, axis=-1)

fig, ax = plt.subplots()
values, bins, _ = ax.hist(X_bars, bins=25)

plt.show()

print("P value for shapiro-Wilk test:", shapiro(X_bars).pvalue)
# Out:
# P value for shapiro-Wilk test: 0.0

# %%
print(X_bars)
# Out:
# [ 3.01570156e+00 -2.65900484e-01 -5.38567528e-01 -5.00896300e-01
#   6.10823961e-01 -7.10040625e-01 -9.04388318e-01  2.17842300e+00
#  -2.51999806e+00 -2.15132167e+00  1.37816977e+00  1.39437097e+00
#   4.02897678e-02  1.60346363e+00 -6.28026103e-01  1.59927043e+01
#   5.53374107e+00  5.65373123e+00  1.47698855e+01 -1.48968108e+00
#  -6.82679820e-02  1.18555509e+00 -1.77044359e+00  1.41532279e+00
#   1.56874476e+01 -5.20643415e-01 -7.09675300e-01  4.07184180e-01
#  -5.24038037e-01 -1.96283820e-01  6.02179970e-01  5.32388947e-02
#   8.07623000e-01  1.24560309e+00 -1.93108827e+01  3.12013939e+00
#   1.49120373e-01  3.98610692e+00 -4.49365902e+00  3.84826325e+00
#   3.31727796e-01 -1.95106085e-01  3.78061757e-01 -3.60414111e-02
#  -5.64037897e-01 -7.79491800e-01  3.62530763e+00 -2.07747932e+01
#  -2.05323402e+00  5.79745357e-01 -9.46000081e+00  9.52147553e-01
#   3.92889135e+00 -3.86041130e+00  1.38532536e-02  1.37284864e+01
# ...
